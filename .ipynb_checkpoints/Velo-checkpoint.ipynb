# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import numpy as np
from time import sleep

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = 'https://www.granfondoguide.com/Events/ProCyclingCalendar2022'
driver.get(url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\adema\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# C:\Users\adema\AppData\Local\Temp\ipykernel_15372\3563009890.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
# initialize storages
date, event, location, route = ([] for i in range(4))
soup = BeautifulSoup(driver.page_source, 'html.parser')
tbody = soup.find('tbody')

# get table data according to their columns and indices
# tr for the titles and td for the data with in them
def get_table_data(col,i):
    for title in tbody.find_all('tr'):
        data = title.find_all('td')[i].text.strip()
        col.append(data)
    return col

# %%
# Uncomment the following function calls

get_table_data(date, 0)
get_table_data(event, 1)
get_table_data(location, 2)
get_table_data(route, 3)
# Out:
# ['Routes',
#  '9 stages',
#  '21 stages',
#  '219km',
#  '7 stages',
#  '21 stages',
#  '250 km',
#  '7 stages',
#  '200km',
#  '206km',
#  '205 km',
#  '255 km',
#  '6 stages',
#  '7 stages',
#  '5 stages',
#  '6 stages',
#  '5 stages',
#  '7 stages',
#  '196 km',
#  '201km',
#  '176 km',
#  '7 stages',
#  '7 stages',
#  '291 km',
#  '7 stages',
#  '203 km',
#  '243 km',
#  '200km',
#  '255km',
#  '6 stages',
#  '208 km',
#  '250 km',
#  '8 stages',
#  '205km',
#  '258 km',
#  '5 stages',
#  '196km',
#  '229 km',
#  '250 km',
#  '6 stages',
#  '217 km']

# %%
# Date column
df = pd.DataFrame(date, columns = {'Date'})

# The function returns a dataframe having their indices removed
# which will help us integrate the columns all together

def define_df(dataframe, title):
    dtf= pd.DataFrame(dataframe, columns = {title})
    dtf.reset_index(drop = True, inplace=True)
    return dtf

df_event = define_df(date, 'Event')
df_loc = define_df(location, 'Location')
df_route  = define_df(route, 'Routes')

# Combine and concatenate the columns data
all_together = [df, df_event, df_loc, df_route]
dff = pd.concat(all_together, axis=1)
# remove the first row
dff.drop(index=df.index[0], axis=0, inplace=True)

#Export to csv file
#dff.to_csv('df.csv')

dff
# Out:
#                 Date             Event                         Location  \
# 1   Jun 12  - Jun 19  Jun 12  - Jun 19               Baar,  Switzerland
# 2   Jul 01  - Jul 24  Jul 01  - Jul 24              Copenhagen, Denmark
# 3             Jul 30            Jul 30             San-Sebastian, Spain
# 4   Aug 08  - Aug 14  Aug 08  - Aug 14                 Radzymin, Poland
# 5   Aug 19  - Sep 11  Aug 19  - Sep 11             Utrecht, Netherlands
# 6             Aug 21            Aug 21                 Hamburg, Germany
# 7   Aug 29  - Sep 04  Aug 29  - Sep 04               Breda, Netherlands
# 8             Sep 09            Sep 09              Quebec City, Canada
# 9             Sep 11            Sep 11                 Montreal, Canada
# 10            Sep 14            Sep 14                Beaufays, Belgium
# 11            Oct 08            Oct 08                   Bergamo, Italy
# 12  Jan 20  - Jan 28  Jan 20  - Jan 28              Adelaide, Australia
# 13  Jan 29  - Feb 05  Jan 29  - Feb 05              San Juan, Argentina
# 14  Feb 01  - Feb 05  Feb 01  - Feb 05      Castelló de la Plana, Spain
# 15  Feb 07  - Feb 12  Feb 07  - Feb 12            Al Sawadi Beach, Oman
# 16  Feb 15  - Feb 19  Feb 15  - Feb 19                  Loule, Portugal
# 17  Feb 19  - Feb 25  Feb 19  - Feb 25  Abu Dhabi, United Arab Emirates
# 18            Feb 25            Feb 25         Ghent, Flanders, Belgium
# 19            Feb 26            Feb 26                  Kuurne, Belgium
# 20            Mar 04            Mar 04            Siena, Tuscany, Italy
# 21  Mar 05  - Mar 12  Mar 05  - Mar 12                    Paris, France
# 22  Mar 06  - Mar 12  Mar 06  - Mar 12          Lido di Camaiore, Italy
# 23            Mar 18            Mar 18                     Milan, Italy
# 24  Mar 20  - Mar 26  Mar 20  - Mar 26                   Calella, Spain
# 25            Mar 24            Mar 24               Harelbeke, Belgium
# 26            Mar 26            Mar 26                   Ghent, Belgium
# 27            Mar 29            Mar 29               Roeselare, Belgium
# 28            Apr 02            Apr 02                 Antwerp, Belgium
# 29  Apr 03  - Apr 08  Apr 03  - Apr 08                Etxebarria, Spain
# 30            Apr 05            Apr 05                 Antwerp, Belgium
# 31            Apr 09            Apr 09          Maastricht, Netherlands
# 32  Apr 10  - Apr 15  Apr 10  - Apr 15                 Istanbul, Turkey
# 33            Apr 12            Apr 12                Overijse, Belgium
# 34            Apr 16            Apr 16                Compiègne, France
# 35  Apr 17  - Apr 21  Apr 17  - Apr 21                      Arco, Italy
# 36            Apr 19            Apr 19       Marche-en-Famenne, Belgium
# 37  Apr 22  - Apr 29  Apr 22  - Apr 29                   Plouay, France
# 38            Apr 23            Apr 23                   Liege, Belgium
# 39            Apr 27            Apr 27   La Chaux-de-Fonds, Switzerland
# 40            Apr 29            Apr 29      Eschborn-Frankfurt, Germany
#
#        Routes
# 1    9 stages
# 2   21 stages
# 3       219km
# 4    7 stages
# 5   21 stages
# 6      250 km
# 7    7 stages
# 8       200km
# 9       206km
# 10     205 km
# 11     255 km
# 12   6 stages
# 13   7 stages
# 14   5 stages
# 15   6 stages
# 16   5 stages
# 17   7 stages
# 18     196 km
# 19      201km
# 20     176 km
# 21   7 stages
# 22   7 stages
# 23     291 km
# 24   7 stages
# 25     203 km
# 26     243 km
# 27      200km
# 28      255km
# 29   6 stages
# 30     208 km
# 31     250 km
# 32   8 stages
# 33      205km
# 34     258 km
# 35   5 stages
# 36      196km
# 37     229 km
# 38     250 km
# 39   6 stages
# 40     217 km

# %%
# filtering out countries that have different stages, the rest countries are in Kilometers which don't have stages
# Let's add each url (link) before and filter them out afterwards to make the process easier
dff[dff.Routes.str.contains('stages')]
# Out:
#                 Date             Event                         Location  \
# 1   Jun 12  - Jun 19  Jun 12  - Jun 19               Baar,  Switzerland
# 2   Jul 01  - Jul 24  Jul 01  - Jul 24              Copenhagen, Denmark
# 4   Aug 08  - Aug 14  Aug 08  - Aug 14                 Radzymin, Poland
# 5   Aug 19  - Sep 11  Aug 19  - Sep 11             Utrecht, Netherlands
# 7   Aug 29  - Sep 04  Aug 29  - Sep 04               Breda, Netherlands
# 12  Jan 20  - Jan 28  Jan 20  - Jan 28              Adelaide, Australia
# 13  Jan 29  - Feb 05  Jan 29  - Feb 05              San Juan, Argentina
# 14  Feb 01  - Feb 05  Feb 01  - Feb 05      Castelló de la Plana, Spain
# 15  Feb 07  - Feb 12  Feb 07  - Feb 12            Al Sawadi Beach, Oman
# 16  Feb 15  - Feb 19  Feb 15  - Feb 19                  Loule, Portugal
# 17  Feb 19  - Feb 25  Feb 19  - Feb 25  Abu Dhabi, United Arab Emirates
# 21  Mar 05  - Mar 12  Mar 05  - Mar 12                    Paris, France
# 22  Mar 06  - Mar 12  Mar 06  - Mar 12          Lido di Camaiore, Italy
# 24  Mar 20  - Mar 26  Mar 20  - Mar 26                   Calella, Spain
# 29  Apr 03  - Apr 08  Apr 03  - Apr 08                Etxebarria, Spain
# 32  Apr 10  - Apr 15  Apr 10  - Apr 15                 Istanbul, Turkey
# 35  Apr 17  - Apr 21  Apr 17  - Apr 21                      Arco, Italy
# 39            Apr 27            Apr 27   La Chaux-de-Fonds, Switzerland
#
#        Routes
# 1    9 stages
# 2   21 stages
# 4    7 stages
# 5   21 stages
# 7    7 stages
# 12   6 stages
# 13   7 stages
# 14   5 stages
# 15   6 stages
# 16   5 stages
# 17   7 stages
# 21   7 stages
# 22   7 stages
# 24   7 stages
# 29   6 stages
# 32   8 stages
# 35   5 stages
# 39   6 stages

# %% [markdown]
# #### Finding links

# %%
store_links = []
for tr in tbody.find_all('td', {'class' : 'colTitle'}):
    for a in tr.find_all('a', href = True):
        store_links.append(a['href'])
        print(a['href'])
# Out:
# https://www.granfondoguide.com/Events/Index/6027/2022-tour-of-suisse
# https://www.granfondoguide.com/Events/Index/7004/2022-tour-de-france
# https://www.granfondoguide.com/Events/Index/6002/2022-clásica-san-sebastián
# https://www.granfondoguide.com/Events/Index/6011/2022-tour-of-poland
# https://www.granfondoguide.com/Events/Index/6004/2022-la-vuelta
# https://www.granfondoguide.com/Events/Index/6013/2022-euroeyes-cyclassics-hamburg
# https://www.granfondoguide.com/Events/Index/6003/2022-benelux-tour
# https://www.granfondoguide.com/Events/Index/6005/2022-grand-prix-cycliste-de-quebec
# https://www.granfondoguide.com/Events/Index/6006/2022-grand-prix-cycliste-de-montreal
# https://www.granfondoguide.com/Events/Index/6930/2022-grand-prix-de-wallonie
# https://www.granfondoguide.com/Events/Index/6007/2022-il-lombardia
# https://www.granfondoguide.com/Events/Index/5933/santos-festival-of-cycling
# https://www.granfondoguide.com/Events/Index/6532/2023-vuelta-a-san-juan
# https://www.granfondoguide.com/Events/Index/9305/v2023-volta-a-la-comunitat-valenciana
# https://www.granfondoguide.com/Events/Index/6569/2023-tour-of-oman
# https://www.granfondoguide.com/Events/Index/9306/2023-volta-ao-algarve
# https://www.granfondoguide.com/Events/Index/7990/2023-uae-tour
# https://www.granfondoguide.com/Events/Index/5937/2023-omloop-het-nieuwsblad
# https://www.granfondoguide.com/Events/Index/5982/2023-kuurne-brussels-kuurne
# https://www.granfondoguide.com/Events/Index/5938/2023-strade-bianche
# https://www.granfondoguide.com/Events/Index/5939/2023-paris-nice
# https://www.granfondoguide.com/Events/Index/5983/2023-tirreno-adriatico
# https://www.granfondoguide.com/Events/Index/5989/2023-milano-sanremo
# https://www.granfondoguide.com/Events/Index/5990/2023-volta-a-catalunya
# https://www.granfondoguide.com/Events/Index/5991/2023-e3-saxo-bank-classic
# https://www.granfondoguide.com/Events/Index/5985/2023-gent-wevelgem
# https://www.granfondoguide.com/Events/Index/5984/2023-dwars-door-vlaanderen
# https://www.granfondoguide.com/Events/Index/5986/2022-ronde-van-vlaanderen
# https://www.granfondoguide.com/Events/Index/5995/2023-tour-of-the-basque-country
# https://www.granfondoguide.com/Events/Index/5987/2023-scheldeprijs
# https://www.granfondoguide.com/Events/Index/6001/2023-amstel-gold-race
# https://www.granfondoguide.com/Events/Index/6009/2023-presidential-cycling-tour-of-turkey
# https://www.granfondoguide.com/Events/Index/5988/2023-brabantse-pijl
# https://www.granfondoguide.com/Events/Index/5996/2023-paris-roubaix
# https://www.granfondoguide.com/Events/Index/7185/2023-tour-of-the-alps
# https://www.granfondoguide.com/Events/Index/5997/2023-la-fleche-wallonne
# https://www.granfondoguide.com/Events/Index/6014/2023-brittany-classic-ouest-france
# https://www.granfondoguide.com/Events/Index/5998/2023-liege-bastogne-liege
# https://www.granfondoguide.com/Events/Index/5999/2023-tour-de-romandie
# https://www.granfondoguide.com/Events/Index/6010/2023-eschborn-frankfurt

# %%
# As stated earlier, let's integrate the links in csv format along with the previous data
df_url = pd.DataFrame(store_links, columns={'URLs'})
all_together = [df, df_event, df_loc, df_route, df_url]
dff = pd.concat(all_together, axis=1)
dff
# Out:
#                 Date             Event                         Location  \
# 0               Date              Date                         Location
# 1   Jun 12  - Jun 19  Jun 12  - Jun 19               Baar,  Switzerland
# 2   Jul 01  - Jul 24  Jul 01  - Jul 24              Copenhagen, Denmark
# 3             Jul 30            Jul 30             San-Sebastian, Spain
# 4   Aug 08  - Aug 14  Aug 08  - Aug 14                 Radzymin, Poland
# 5   Aug 19  - Sep 11  Aug 19  - Sep 11             Utrecht, Netherlands
# 6             Aug 21            Aug 21                 Hamburg, Germany
# 7   Aug 29  - Sep 04  Aug 29  - Sep 04               Breda, Netherlands
# 8             Sep 09            Sep 09              Quebec City, Canada
# 9             Sep 11            Sep 11                 Montreal, Canada
# 10            Sep 14            Sep 14                Beaufays, Belgium
# 11            Oct 08            Oct 08                   Bergamo, Italy
# 12  Jan 20  - Jan 28  Jan 20  - Jan 28              Adelaide, Australia
# 39            Apr 27            Apr 27   La Chaux-de-Fonds, Switzerland
#
#        Routes                                               URLs
# 1    9 stages  https://www.granfondoguide.com/Events/Index/70...
# 2   21 stages  https://www.granfondoguide.com/Events/Index/60...
# 4    7 stages  https://www.granfondoguide.com/Events/Index/60...
# 5   21 stages  https://www.granfondoguide.com/Events/Index/60...
# 7    7 stages  https://www.granfondoguide.com/Events/Index/60...
# 12   6 stages  https://www.granfondoguide.com/Events/Index/65...
# 13   7 stages  https://www.granfondoguide.com/Events/Index/93...
# 14   5 stages  https://www.granfondoguide.com/Events/Index/65...
# 15   6 stages  https://www.granfondoguide.com/Events/Index/93...
# 16   5 stages  https://www.granfondoguide.com/Events/Index/79...
# 17   7 stages  https://www.granfondoguide.com/Events/Index/59...
# 21   7 stages  https://www.granfondoguide.com/Events/Index/59...
# 22   7 stages  https://www.granfondoguide.com/Events/Index/59...
# 24   7 stages  https://www.granfondoguide.com/Events/Index/59...
# 29   6 stages  https://www.granfondoguide.com/Events/Index/59...
# 32   8 stages  https://www.granfondoguide.com/Events/Index/59...
# 35   5 stages  https://www.granfondoguide.com/Events/Index/59...
# 39   6 stages  https://www.granfondoguide.com/Events/Index/60...

# %%
# Links related only to countries that have stages
pd.set_option('max_colwidth', 100) # if not set, otherwise doesn't show the full link and when you click it won't work
stage_urls = []
stage_links = dff[dff.Routes.str.contains('stages')].URLs
stage_urls.append(str(stage_links))
stage_links
# Out:
# 1                       https://www.granfondoguide.com/Events/Index/7004/2022-tour-de-france
# 2                https://www.granfondoguide.com/Events/Index/6002/2022-clásica-san-sebastián
# 4                            https://www.granfondoguide.com/Events/Index/6004/2022-la-vuelta
# 5          https://www.granfondoguide.com/Events/Index/6013/2022-euroeyes-cyclassics-hamburg
# 7        https://www.granfondoguide.com/Events/Index/6005/2022-grand-prix-cycliste-de-quebec
# 12                   https://www.granfondoguide.com/Events/Index/6532/2023-vuelta-a-san-juan
# 13    https://www.granfondoguide.com/Events/Index/9305/v2023-volta-a-la-comunitat-valenciana
# 14                        https://www.granfondoguide.com/Events/Index/6569/2023-tour-of-oman
# 15                    https://www.granfondoguide.com/Events/Index/9306/2023-volta-ao-algarve
# 16                            https://www.granfondoguide.com/Events/Index/7990/2023-uae-tour
# 17               https://www.granfondoguide.com/Events/Index/5937/2023-omloop-het-nieuwsblad
# 21                   https://www.granfondoguide.com/Events/Index/5983/2023-tirreno-adriatico
# 22                      https://www.granfondoguide.com/Events/Index/5989/2023-milano-sanremo
# 24                https://www.granfondoguide.com/Events/Index/5991/2023-e3-saxo-bank-classic
# 29                        https://www.granfondoguide.com/Events/Index/5987/2023-scheldeprijs
# 32                      https://www.granfondoguide.com/Events/Index/5988/2023-brabantse-pijl
# 35                  https://www.granfondoguide.com/Events/Index/5997/2023-la-fleche-wallonne
# 39                  https://www.granfondoguide.com/Events/Index/6010/2023-eschborn-frankfurt
# Name: URLs, dtype: object
